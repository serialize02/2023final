# %% [markdown]
# <a href="https://colab.research.google.com/github/serialize02/2023final/blob/main/dimensionality_reduction(PCA)_ipynb_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://medium.com/analytics-vidhya/dimensionality-reduction-principal-component-analysis-d1402b58feb1

# %% [markdown]
# 키랑 몸무게가 대충 정비례하는 것처럼,
# 정보적 측면에서 어차피 키와 몸무게가 같이 가는데 두 정보 다 필요한가?
# 둘이 상관관계가 있으니까 하나로 줄여보자
# 키+몸무게 -> 크기
# 영어능력+국어능력 -> 언어능력
#
# pca를 이용해서 차원을 축소할 수 있음
# principle component analysis
# =decorrelation
# 90도로 만들어서 둘이 아예 상관관계가 없도록
# 한 축 pc1, 다른 축 pc2
#
# 원래 데이터가 변수가 2개면 pca 거쳐도 변수는 2개인데 그 중 우리는 의미있는 것을 선택하면 됨
#
# 이 경우 입력과 출력이 없음, 그냥 데이터 여러개
# correlation 이 돼 있을지도 모르는 4개의 변수를 decorrelation 된 4개의 변수로 바꿔준다고 생각하면 됨
#
# -> unsupervised 라고 생각
# 차원 축소

# %% [markdown]
# ## Loading a dataset

# %%
import pandas as pd
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'label'])
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
X = iris.drop(['label'], axis=1)
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Principal Component Analysis (PCA)

# %%
from sklearn.decomposition import PCA
model = PCA(n_components=2)  # n_components specifies the new dimensionality
X_reduced = model.fit(X).transform(X) # or just pca.fit_transform(X)
pd.DataFrame(X_reduced)
# Out:
#             0         1
# 0   -2.684207  0.326607
# 1   -2.715391 -0.169557
# 2   -2.889820 -0.137346
# 3   -2.746437 -0.311124
# 4   -2.728593  0.333925
# ..        ...       ...
# 145  1.944017  0.187415
# 146  1.525664 -0.375021
# 147  1.764046  0.078519
# 148  1.901629  0.115877
# 149  1.389666 -0.282887
#
# [150 rows x 2 columns]

# %% [markdown]
# 긴 데이터에 해당하는 축이 pc1, 데이터가 좁은 폭이 pc2

# %%
print('Components:', model.components_)
print('Explained Variance:', model.explained_variance_)
print('Explained Variance Ratio:', model.explained_variance_ratio_ )
# Out:
# Components: [[ 0.36158968 -0.08226889  0.85657211  0.35884393]
#  [ 0.65653988  0.72971237 -0.1757674  -0.07470647]]
# Explained Variance: [4.22484077 0.24224357]
# Explained Variance Ratio: [0.92461621 0.05301557]

# %% [markdown]
# 숫자 4개짜리 2개
# 첫번째는 pc1, 두번째는 pc2에 해당되는 방향 (벡터)
# 크기는 무조건 1이니까 중요하지 않고 방향 정보만 생각하면 됨
#
# 두번째 줄은 데이터의 폭 당연히 pc1이 크고 pc2가 작겠지
# 마지막 줄이 얼마나 오차가 있는가
# 꽃받침과 꽃잎조차도 correlation이 있어도 아 숫자 하나여도 괜찮다 ~

# %% [markdown]
# inverse -> 복원
# 정보를 조금 잃어서 살짝 부정확하지만 ㄱㅊ은 정도
#
# 5.087 -> 5.1 비슷함

# %%
X_approx = model.inverse_transform(X_reduced)
pd.DataFrame(X_approx)
# Out:
#             0         1         2         3
# 0    5.087182  3.513156  1.402043  0.211056
# 1    4.750155  3.153664  1.462541  0.236932
# 2    4.708232  3.191519  1.307469  0.171933
# 3    4.645984  3.052915  1.460831  0.236367
# 4    5.075937  3.522147  1.362737  0.194581
# ..        ...       ...       ...       ...
# 145  6.669315  3.030827  5.390916  1.882264
# 146  6.148781  2.654828  5.131424  1.774158
# 147  6.532745  2.966170  5.255898  1.825818
# 148  6.607020  2.982112  5.367182  1.872398
# 149  6.160096  2.733248  4.998738  1.718473
#
# [150 rows x 4 columns]

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# 사회과학에서 pca 는 필수 !! 학문적으로 의미를 줄 수 있기 때문에
# independent한 정보를 가져와
